# %%
import sys
import xlsxwriter
import pandas as pd
import sys
import mysql.connector
import os
from dotenv import load_dotenv
from datetime import date

today = date.today()
load_dotenv()

#configurar la conexion a la base de datos
DB_USERNAME = os.getenv('DB_USERNAME')
DB_DATABASE = os.getenv('DB_DATABASE')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_PORT = os.getenv('DB_PORT')
DB_HOST=os.getenv('DB_HOST')

# Conectar a DB
cnx = mysql.connector.connect(user=DB_USERNAME,
                              password=DB_PASSWORD,
                              host=DB_HOST,
                              port=DB_PORT,
                              database=DB_DATABASE,
                              use_pure=False)

# %%
reactivos=pd.read_sql('select * from reactivos ',cnx)
opciones=pd.read_sql('select * from options ',cnx)
# Out:
# c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
for i in reactivos['section'].unique():
    print('SECCION ' + str(i))
    print('')
    r=reactivos.loc[reactivos['section']==i];
    r=r.sort_values(by=['order'])
    for j in range(len(r)):
        print('',r['order'].values[j],r['description'].values[j])
        o=opciones.loc[opciones['reactivo']==r['clave'].values[j]]
        if(r['archtype'].values[j]):
            o=o=opciones.loc[opciones['reactivo']==r['archtype'].values[j]]
        for k in range(len(o)):
            print('','-',o['descripcion'].values[k])
# Out:
# SECCION A
#
#  1.1 ¿Cuál es su estado civil?
#  - Soltero
#  - Casado
#  - Divorciado
#  - Unión Libre
#  - Viudo
#  2.0 ¿Tiene hijos?
#  - Sí
#  - No
#  2.1 ¿Cuántos?
#  3.0 ¿Cuál es el último grado de estudios de su pareja?
#  - Sin instrucción
#  - Primaria
#  - Carrera técnica o comercial después de primaria
#  - Secundaria
#  - Escuela Normal
#  - Carrera técnica o comercial después de secundaria
#  - Bachillerato o vocacional
#  - Escuela Normal Superior
#  - Carrera técnica o comercial después de bachillerato
#  - Licenciatura
#  - Posgrado
#  - Lo desconoce
#  - Otro
#  - Licenciatura Trunca
#  3.1 Otro:
#  4.0 ¿Cuál es la ocupación de su pareja?
#  - Funcionarios directivos y jefes
#  - Profesionistas y técnicos
#  - Auxiliares en actividades administrativas
#  - Comerciantes, empleados en ventas, agentes de ventas
#  - Trabajadores en servicios personales y de vigilancia
#  - Trabajadores en actividades agrícolas y ganaderas
# ...

# %%
opciones.columns
# Out:
# Index(['id', 'clave', 'description', 'type', 'rules', 'section', 'order',
#        'archtype', 'child', 'aux', 'extra_label', 'created_at', 'updated_at'],
#       dtype='object')

# %%
from Cryptodome.Cipher import AES
import hashlib
import sys
import binascii

key='"E"Y\x03"'
plaintext = "308106325"
cipher = "aes-128-gcm"
plaintext='hello how are you?'
password='qwerty123'


if (len(sys.argv)>1):
  plaintext=(sys.argv[1])
if (len(sys.argv)>2):
  password=(sys.argv[2])

# %%
cipher_config = AES.new(key.encode("utf-8"), AES.MODE_CBC, substring_iv.encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 cipher_config = AES.new(key.encode("utf-8"), AES.MODE_CBC, substring_iv.encode("utf-8"))
#
# NameError: name 'substring_iv' is not defined

# %%
from Cryptodome.Cipher import AES
import hashlib
import sys
import binascii


plaintext='hello how are you?'
password='qwerty123'

if (len(sys.argv)>1):
  plaintext=(sys.argv[1])
if (len(sys.argv)>2):
  password=(sys.argv[2])

def encrypt(plaintext,key, mode):
  encobj = AES.new(key, AES.MODE_GCM)
  ciphertext,authTag=encobj.encrypt_and_digest(plaintext)
  return(ciphertext,authTag,encobj.nonce)

def decrypt(ciphertext,key, mode):
  (ciphertext,  authTag, nonce) = ciphertext
  encobj = AES.new(key,  mode, nonce)
  return(encobj.decrypt_and_verify(ciphertext, authTag))

key = hashlib.sha256(password.encode()).digest()

print("GCM Mode: Stream cipher and authenticated")
print("\nMessage:\t",plaintext)
print("Key:\t\t",password)


ciphertext = encrypt(plaintext.encode(),key,AES.MODE_GCM)

print("Cipher:\t\t",binascii.hexlify(ciphertext[0]))
print("Auth Msg:\t",binascii.hexlify(ciphertext[1]))
print("Nonce:\t\t",binascii.hexlify(ciphertext[2]))


res= decrypt(ciphertext,key,AES.MODE_GCM)


print ("\n\nDecrypted:\t",res.decode())
# Out:
# GCM Mode: Stream cipher and authenticated
#
# Message:	 --f=c:\Users\fgonzalez\AppData\Roaming\jupyter\runtime\kernel-v31bd7e6f76ba7b472cc5d3073f17a133ac5ac9618.json
# Key:		 qwerty123
# Cipher:		 b'b9d2001d7429a3c93e1e6346ead8fb4a9e06c272f7c9131264d3fe4f9fa3ee15878b8694a3e302cd5c3fc510fffdd88b1a2d0f80ee507f70bffcf6d4f0e1400c5ae641b6683df2bace820e2ace7ca5e2a40071bf2443c1576d58a9889300cab6d0afea4dc65caf44cc895d8129'
# Auth Msg:	 b'06096cbe4891662e1b53a0e230461d9e'
# Nonce:		 b'a80e574ec580f682235fc0365ca26f56'
#
#
# Decrypted:	 --f=c:\Users\fgonzalez\AppData\Roaming\jupyter\runtime\kernel-v31bd7e6f76ba7b472cc5d3073f17a133ac5ac9618.json

# %%
print(res)
# Out:
# b'--f=c:\\Users\\fgonzalez\\AppData\\Roaming\\jupyter\\runtime\\kernel-v31bd7e6f76ba7b472cc5d3073f17a133ac5ac9618.json'

# %%
import Cryptodome

# %%
# !pip install Crypto
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#cifrado modular
import math

def encriptar(x,e,n):
    cipher=''
    for i in range(len(x)):
        cipher +=str(int(math.pow(int(x[i]),e)%n))
    return(hex(int(cipher)))
def desencriptar(x,d,n):
    cipher=int(x,16)
    for i in range(len(x)):
        cipher +=str(int(math.pow(int(x[i]),d)%n))
    return(hex(int(cipher)))

# %%
e
# Out:
# 5

# %%
encriptar('308106325',a,b)
# Out:
# '0x15a2c62ca'

# %%
int('0x15a2c62ca',16)
# Out:
# 5807825610

# %%
c=0
for i in range(0,13):
    print(i,(math.pow(i,11)+c)%27)
# Out:
# 0 0.0
# 1 1.0
# 2 4.0
# 3 5.0
# 4 2.0
# 5 3.0
# 6 6.0
# 7 7.0
# 8 8.0
# 9 11.0
# 10 12.0
# 11 9.0
# 12 10.0

# %%
for i in range(0,13):
    print(i,(math.pow(i,7)+c)%13)
# Out:
# 0 0.0
# 1 1.0
# 2 11.0
# 3 3.0
# 4 4.0
# 5 8.0
# 6 7.0
# 7 6.0
# 8 5.0
# 9 9.0
# 10 10.0
# 11 2.0
# 12 12.0

# %%
hex(13)[2]
# Out:
# 'd'

# %%
import math


def gcd(a, h):
    temp = 0
    while(1):
        temp = a % h
        if (temp == 0):
            return h
        a = h
        h = temp


p = 7
q =7
n = p*q
e = 2
phi = (p-1)*(q-1)

while (e < phi):

    # e must be co-prime to phi and
    # smaller than phi.
    if(gcd(e, phi) == 1):
        break
    else:
        e = e+1
k = 2
d = (1 + (k*phi))/e
print(n,e,d,phi)
# Out:
# 49 5 14.6 36

# %%
for i in range(0,phi):
    print(i,i*e%phi)
# Out:
# 0 0
# 1 5
# 2 10
# 3 15
# 4 20
# 5 25
# 6 30
# 7 35
# 8 4
# 9 9
# 10 14
# 11 19
# 12 24
# 13 29
# 14 34
# 15 3
# 16 8
# 17 13
# 18 18
# 19 23
# 20 28
# 21 33
# 22 2
# 23 7
# 24 12
# 25 17
# 26 22
# 27 27
# 28 32
# 29 1
# 30 6
# 31 11
# 32 16
# 33 21
# 34 26
# 35 31

# %%
math.pow(math.pow(18,e)%n,29)%n
# Out:
# 38.0

# %%
for i in range(0,n):
    cipher=(math.pow(i,e))%n
    decif=(math.pow(cipher,d))%n
    print(i,cipher,decif)
# Out:
# 0 0.0 0.0
# 1 1.0 1.0
# 2 32.0 3.375
# 3 33.0 6.75
# 4 9.0 24.520453929901123
# 5 10.0 34.80194282531738
# 6 6.0 8.557215265929699
# 7 7.0 31.48791855573654
# 8 8.0 25.447859406471252
# 9 4.0 32.007222604355775
# 10 5.0 16.403102503158152
# 11 16.0 8.2030029296875
# 12 17.0 17.239990234375
# 13 13.0 30.6407470703125
# 14 14.0 6.61639404296875
# 15 15.0 20.22601318359375
# 16 11.0 2.4446964263916016
# 17 12.0 12.895751953125
# 18 23.0 11.33203125
# 19 24.0 23.43359375
# 20 20.0 22.3349609375
# 21 21.0 7.3203125
# 22 22.0 25.93359375
# 23 18.0 23.913330078125
# 24 19.0 34.8916015625
# 25 30.0 30.375
# 26 31.0 2.0
# 27 27.0 9.8125
# 28 28.0 18.71875
# 29 29.0 19.96875
# 30 25.0 10.546875
# 31 26.0 14.390625
# 32 2.0 16.44377681523156
# 33 3.0 11.086480379897694
# 34 34.0 27.375

# %%
n=91
d=5
e=29

# %%
#cifrado modular
import math

def encriptar(x,e,n):
    cipher=''
    for i in range(len(x)):
        block=str(hex(int(math.pow(int(x[i]),e)%n)))[2:].zfill(2)
        print(int(math.pow(int(x[i]),e)%n),block)
        cipher +=block
    return(cipher)
def desencriptar(x,d,n):
    decif=''
    for i in range(int(len(x)/2)):
        print(int(x[i*2:i*2+2],16),str(int(math.pow(int(x[i*2:i*2+2],16),d)%n)))
        decif+=str(int(math.pow(int(x[i*2:i*2+2],16),d)%n))
        # cipher +=str(int(math.pow(int(x[i]),d)%n))
    return(decif)
encriptar('308106325',e,n)
# Out:
# 61 3d
# 0 00
# 8 08
# 1 01
# 0 00
# 41 29
# 61 3d
# 32 20
# 90 5a
# '3d00080100293d205a'

# %%
desencriptar('3d00080100293d205a',d,n)
# Out:
# 61 3
# 0 0
# 8 8
# 1 1
# 0 0
# 41 6
# 61 3
# 32 2
# 90 90
# '3081063290'

# %%
int('0x80',16)
# Out:
# 128

# %%
hex(8)
# Out:
# '0x8'
